# %% [markdown]
# ¡Hola, Manuel!
#
# Mi nombre es Tonatiuh Cruz. Me complace revisar tu proyecto hoy.
#
# Al identificar cualquier error inicialmente, simplemente los destacaré. Te animo a localizar y abordar los problemas de forma independiente como parte de tu preparación para un rol como data-analyst. En un entorno profesional, tu líder de equipo seguiría un enfoque similar. Si encuentras la tarea desafiante, proporcionaré una pista más específica en la próxima iteración.
#
# Encontrarás mis comentarios a continuación - **por favor no los muevas, modifiques o elimines**.
#
# Puedes encontrar mis comentarios en cajas verdes, amarillas o rojas como esta:
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Éxito. Todo está hecho correctamente.
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Observaciones. Algunas recomendaciones.
# </div>
#
# <div class="alert alert-block alert-danger">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Necesita corrección. El bloque requiere algunas correcciones. El trabajo no puede ser aceptado con comentarios en rojo.
# </div>
#
# Puedes responderme utilizando esto:
#
# <div class="alert alert-block alert-info">
# <b>Respuesta del estudiante.</b> <a class="tocSkip"></a>

# %%
import pandas as pd
import numpy as np
cab_company = pd.read_csv('/datasets/project_sql_result_01.csv')
print(cab_company)
cab_company.info()
# Out:
#                        company_name  trips_amount
# 0                         Flash Cab         19558
# 1         Taxi Affiliation Services         11422
# 2                 Medallion Leasing         10367
# 3                        Yellow Cab          9888
# 4   Taxi Affiliation Service Yellow          9299
# ..                              ...           ...
# 59     4053 - 40193 Adwar H. Nikola             7
# 60          2733 - 74600 Benny Jona             7
# 61    5874 - 73628 Sergey Cab Corp.             5
# 62       2241 - 44667 - Felman Corp             3
# 63      3556 - 36214 RC Andrews Cab             2
#
# [64 rows x 2 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   company_name  64 non-null     object
#  1   trips_amount  64 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 1.1+ KB

# %%
import pandas as pd
import numpy as np
neighborhood_end = pd.read_csv('/datasets/project_sql_result_04.csv')
print(neighborhood_end)
neighborhood_end.info()
# Out:
#    dropoff_location_name  average_trips
# 0                   Loop   10727.466667
# 1            River North    9523.666667
# 2          Streeterville    6664.666667
# 3              West Loop    5163.666667
# 4                 O'Hare    2546.900000
# ..                   ...            ...
# 89       Mount Greenwood       3.137931
# 90             Hegewisch       3.117647
# 91              Burnside       2.333333
# 92             East Side       1.961538
# 93             Riverdale       1.800000
#
# [94 rows x 2 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 94 entries, 0 to 93
# Data columns (total 2 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   dropoff_location_name  94 non-null     object
#  1   average_trips          94 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 1.6+ KB

# %%
trips_loop_to_airport_O_Hare = pd.read_csv('/datasets/project_sql_result_07.csv')
print(trips_loop_to_airport_O_Hare)
trips_loop_to_airport_O_Hare.info()
# Out:
#                  start_ts weather_conditions  duration_seconds
# 0     2017-11-25 16:00:00               Good            2410.0
# 1     2017-11-25 14:00:00               Good            1920.0
# 2     2017-11-25 12:00:00               Good            1543.0
# 3     2017-11-04 10:00:00               Good            2512.0
# 4     2017-11-11 07:00:00               Good            1440.0
# ...                   ...                ...               ...
# 1063  2017-11-25 11:00:00               Good               0.0
# 1064  2017-11-11 10:00:00               Good            1318.0
# 1065  2017-11-11 13:00:00               Good            2100.0
# 1066  2017-11-11 08:00:00               Good            1380.0
# 1067  2017-11-04 16:00:00                Bad            2834.0
#
# [1068 rows x 3 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1068 entries, 0 to 1067
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ...

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Recuerda que como buena prática es recomendable cargar todas las bases de datos en una misma celda. Es por ello que te recomiendo cargar la base faltante en esta misma celda..</div>
#
# ¿Por base faltante te refieres a la ultima que nos indican en el paso 5, la de /datasets/project_sql_result_07.csv?
# ¿Entonces eso significaria que no va abajo al inicio del paso 5 sino, aqui aerriba, verdad?

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Exacto, la base del paso 5. Gran trabajo con el ajuste!

# %%
# Los 10 barrios con mayor finalizacion de servicio
neighborhood_end.head(10)
# Out:
#   dropoff_location_name  average_trips
# 0                  Loop   10727.466667
# 1           River North    9523.666667
# 2         Streeterville    6664.666667
# 3             West Loop    5163.666667
# 4                O'Hare    2546.900000
# 5             Lake View    2420.966667
# 6            Grant Park    2068.533333
# 7         Museum Campus    1510.000000
# 8            Gold Coast    1364.233333
# 9    Sheffield & DePaul    1259.766667

# %%
import seaborn as sns
import matplotlib.pyplot as plt
neighbor_end = neighborhood_end.head(10)
plt.figure(figsize=(7,7))
sns.barplot(data = neighbor_end, x = 'dropoff_location_name', y = 'average_trips')
plt.xlabel("Neighborhood End")
plt.xticks(rotation=90)
plt.ylabel("Average Trips")
plt.suptitle('Los 10 destinos mas comunes')
plt.title('Del 15 al 16 de noviembre de 2017')
plt.show()

# %%
# Es notable la difrencia del numero de viajes de taxi de los destinos mas populares, a los ultimos 6 en esta lista
# Considero que los primeros deben tener relacion con ser areas con mucha asistencia laboral y de manera secundaria
# recreattiva y turistica.

# %%
cab_company = cab_company.head(10)
plt.figure(figsize=(10,7))
sns.barplot(data = cab_company, x = 'company_name', y = 'trips_amount')
plt.xlabel("Cab Company")
plt.xticks(rotation=90)
plt.ylabel("Trips Amount")
plt.suptitle('Viajes por compañia')
plt.title('Del 15 al 16 de noviembre de 2017')
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Muy buen trabajo con el desarrollo de la gráfica para visualizar los resultados. Solamente dado que al cliente le interesa el top 10 de las principales empresas con número de viajes, te recomiendo complementar este análisis con una gráfica solamente mostrando el top 10.</div>
#
# ¡Cambio realizado!

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
#  Gran trabajo con el ajuste!

# %%
# Queda afirmado Flash Cab es la compañia con mas taxis en la ciudad, inluso puede ser una de las mas
# antiguas de la localidad, superando facilmente a Taxi Afiliation Services con mas de un 75% mas de viajes.
# Incluso la diferencia entre el TAS (2o lugar) y Blue Ribbon Taxi (10o Lugar), es muy similar en diferencias
# como la 1a y 2a, del 2o a al 10o lugar, la disminucion de servicios es gradual, disminuyendo de una a otra
# entre el 10% o un menor porcentaje, como el caso entre de Taxi Afiliation Services Yellow y Chicago Carriage
# donde la diferencia parece ser cercana a menos del 3%

# %%
# Prueba la hipótesis:
# 1. La duración promedio de los viajes desde el Loop hasta el Aeropuerto Internacional O'Hare
# cambia los sábados lluviosos.

# Establece tu mismo el valor de umbral alfa.
# Explica:
# Cómo formulaste las hipótesis nula y alternativa.
# Qué criterio utilizaste para probar las hipótesis y por qué.

# HO: La duración promedio de los viajes desde el Loop hasta el Aeropuerto Internacional O'Hare es igual aun en sábados lluviosos
# H1: La duración promedio de los viajes desde el Loop hasta el Aeropuerto Internacional O'Hare cambia sábados lluviosos

from scipy.stats import levene
import numpy as np

good_weather = trips_loop_to_airport_O_Hare[trips_loop_to_airport_O_Hare['weather_conditions']=='Good']
bad_weather = trips_loop_to_airport_O_Hare[trips_loop_to_airport_O_Hare['weather_conditions']=='Bad']

# Realizar la prueba de Levene
est_estadistico, p_valor = levene(good_weather['duration_seconds'], bad_weather['duration_seconds'])

# Imprimir resultados
print("Estadístico de Levene:", est_estadistico)
print("P-valor:", p_valor)

# Interpretar el resultado
alpha = 0.05  # Nivel de significancia
if p_valor < alpha:
    print("Rechazamos la hipótesis nula: Las varianzas no son iguales")
else:
    print("No rechazamos la hipótesis nula: Las varianzas son iguales")
print()

from scipy import stats as st
import numpy as np

print('Media good_weather:', good_weather['duration_seconds'].mean(), ' - Desviación estándar:', good_weather['duration_seconds'].std())
print('Media bad_weather:', bad_weather['duration_seconds'].mean(), ' - Desviación estándar:', bad_weather['duration_seconds'].std())

estadistico, pvalue = st.ttest_ind(good_weather['duration_seconds'], bad_weather['duration_seconds'], equal_var=True)
alpha = 0.05
if pvalue < alpha:
    print('Se rechaza la hipotesis nula: La duración promedio de los viajes cambia en los sábados lluviosos')
elif pvalue >= alpha:
    print('No se puede rechazar la hipotesis nula: La duración promedio de los viajes es igual aun en los sábados lluviosos')
# Out:
# Estadístico de Levene: 0.38853489683656073
# P-valor: 0.5332038671974493
# No rechazamos la hipótesis nula: Las varianzas son iguales
#
# Media good_weather: 1999.6756756756756  - Desviación estándar: 759.1982677071313
# Media bad_weather: 2427.2055555555557  - Desviación estándar: 721.3141382244514
# Se rechaza la hipotesis nula: La duración promedio de los viajes cambia en los sábados lluviosos

# %% [markdown]
#  <div class="alert alert-block alert-danger">
# <b>Comentario revisor</b> <a class="tocSkip"></a>
#
# Para esta prueba te recomiendo hacer una prueba de  Levene  para mostrar si las varianzas son iguales y agregarlo dentro de la función. Actualmente lo colocas como equal_var=False. Para esto, primero debes calcular las varianzas para cada uno de los días (lluvioso y no lluvioso) debes de hacer uso de la siguiente función:
#
#     levene(good_weather['duration_seconds'], bad_weather['duration_seconds'])
#
# Adoptaremos un nivel de significancia de 0.05; si el valor p resultante es mayor a 0.05, no podemos rechazar la hipótesis nula, y si es menor a 0.05, rechazamos la hipótesis nula, indicando que las varianzas no son iguales.
#
# Solamente recuerda que la prueba de levene no es sustituto a la prueba de st.ttest_ind, más bien es complemento para saber que colocar dentro del elemento "equal_var".  Es por eso que para terminar la prueba debes de realizar la prueba de st.ttest_ind considernado el resultado de la prueba realizada de levene.
# </div>
#
# Segun entendi tus instrucciones, al aplicar la prueba de levene y obtener en este caso un P-valor: 0.5332038671974493, el valor alfa para mi prueba st.ttest seria de forma correcta el valor alpha 0.05 y el parametro correcto sera "equal_var=False", verdad?
# ¿Caso contrario cual deberia ser el valor alpha si el P-valor es inferior a 5 o solo seria usar el parametro "equal_var=True"?

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
#  Gran trabajo con el ajuste! Solamente en este caso como obtienes un valor mayor a 0.05 en la prueba de levene las varianzas son iguales. Por lo que en la prueba de hipótesis debemos de usar True
#
#
#
# ### Corregido, o al menos eso creo, en la prueba de levene nos da como resultado que las varianzas son iguales y no rechazamos la hipotesis nula. pero en el st.ttest en realidad si hay diferencias en el tiempo de traslado clima bueno vs malo, entonces, se supone que la hipotesis nula es que las cosas permanecen igual ¿estoy en lo correcto? y si las cosas cambian es donde rechazamos la hipotesis nula, ¿Verdad?

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Gran trabajo con el ajuste! Es correcta la interpretación que realizas. Sigue disfrutando los siguientes cursso

# %%
# 1. La igualdad de la media es lo que nos da la pauta para definir la hipotesis nula, una vez establecida
# estal la hipotesis alternativa siempre sera lo contrario de la hipotesis nula, la diferencia de la media.

# 2. Debido a que debi comparar dos poblaciones distintas (2 estadios distintos de clima, bueno o malo) fue que
# elegi usar la hipotesis sobre la igualdad de la media de 2 poblaciones
